# %%
import rasterio
import numpy as np

# %%
with rasterio.open("22103_rtp_a2.tif") as src:
    data = src.read(1)              # read first
    data = data.astype(float)       # convert second
    data[data == -999999.0] = np.nan  # correct nodata value
    print(f"data shape: {data.shape}")
    print(data[0,1600])
# Out:
# data shape: (3730, 3292)
# -71.33069610595703
# /var/folders/04/s_rk8gfn6vq1608hxwwtl_040000gn/T/ipykernel_7472/1666524623.py:2: DeprecationWarning: Setting the shape on a NumPy array has been deprecated in NumPy 2.5.
# As an alternative, you can create a new view using np.reshape (with copy=False if needed).
#   data = src.read(1)              # read first
