# %%
import pandas as pd
import geopandas as gpd

# %%
""" 
seismicity_dependent csv file had 14,127 lines with extra commas in it which 
had to be removed
"""

temp_probe = gpd.read_file("2m_temperature_probe_INGENIOUS_regional_data/2m_temperature_probe_n83geo/2m_temperature_probe_n83geo.shp")
faults_quarternary = gpd.read_file("faults_quaternary_INGENIOUS_regional_data/faults_quaternary_regional.shp")
geodetics = pd.read_csv("geodetics_INGENIOUS_regional_data/geodetic_strain_rate_csv.csv")
great_basin_flows = gpd.read_file("great_basin_q_volcanics/great_basin_flows.shp")
great_basin_vents = gpd.read_file("great_basin_q_volcanics/great_basin_vents.shp")
paleo_geothermal = gpd.read_file("paleo_geothermal_regional/Paleo_geothermal_final.shp")
qfaults = gpd.read_file("qfaults_ingenious_nad83conus117_2023-06-27/qfaults_ingenious_nad83conus117_2023-06-27.shp")
seismicity_dependent = pd.read_csv("seismicity_INGENIOUS_regional_data/dependent_eq/dependent_eq_rate_density_wgs84_csv.csv")
seismicity_independent = pd.read_csv("seismicity_INGENIOUS_regional_data/independent_eq/independent_eq_rate_density_wgs84_csv.csv")
study_area_boundary = gpd.read_file("study_area_boundary_INGENIOUS_regional_data_bp1/GB_study_area_NAD83.shp")
# wellspring = ??????????????, not sure which type of file to read

# %% [markdown]
# # Temp Probe

# %%
temp_probe.head()
# Out:
#    OBJECTID Station          Area     County State   UTM_E    UTM_N  T1m T15m  \
# 0         1   DQ001  Desert Queen  Churchill    NV  340729  4408444  NaN  NaN
# 1         2   DQ002  Desert Queen  Churchill    NV  341657  4406765  NaN  NaN
# 2         3   DQ003  Desert Queen  Churchill    NV  341181  4405689  NaN  NaN
# 3         4   DQ004  Desert Queen  Churchill    NV  340674  4405731  NaN  NaN
# 4         5   DQ005  Desert Queen  Churchill    NV  338490  4405115  NaN  NaN
#
#     T2m  ...     Date_6 T1m_7 T15m_7 T2m_7     Date_7 Org_Stn Link LatDegreeN  \
# 0  23.1  ...        NaT   NaN    NaN   0.0        NaT     Q01  NaN  39.811067
# 1  30.5  ... 2008-10-27   NaN    NaN  25.7 2008-12-10     Q02  NaN  39.796120
# 2  28.7  ...        NaT   NaN    NaN   0.0        NaT     Q03  NaN  39.786342
# 3  29.2  ...        NaT   NaN    NaN   0.0        NaT     Q04  NaN  39.786625
# 4  24.3  ...        NaT   NaN    NaN   0.0        NaT     Q05  NaN  39.780666
#
# ...

# %%
temp_probe.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3800 entries, 0 to 3799
# Data columns (total 47 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    3800 non-null   int64
#  1   Station     3800 non-null   str
#  2   Area        3800 non-null   str
#  3   County      3800 non-null   str
#  4   State       3800 non-null   str
#  5   UTM_E       3800 non-null   int64
#  6   UTM_N       3800 non-null   int64
#  7   T1m         1573 non-null   str
#  8   T15m        1723 non-null   str
#  9   T2m         3800 non-null   float64
#  10  F2mDAB      3800 non-null   float64
#  11  Date        3800 non-null   datetime64[ms]
#  12  Note        3800 non-null   str
#  13  Project     586 non-null    str
#  14  Organizati  3800 non-null   str
#  15  Contact     3654 non-null   str
#  16  Citation    2662 non-null   str
#  17  Notes       170 non-null    str
#  18  T1m_2       108 non-null    str
# ...

# %% [markdown]
# # Faults Quarternary

# %%
faults_quarternary.head()
# Out:
#                                   NAME SLIPRATE_N   RECENCY_N  CODE   NUM  \
# 0  Abert Rim fault, Lake Abert section       0.52     <15,000   123  829a
# 1  Abert Rim fault, Lake Abert section       0.52     <15,000   133  829a
# 2    Abert Rim fault, Northern section       0.06  <1,600,000   154  829b
# 3                    Adobe Range fault       0.01  <1,600,000   254  1561
# 4            Agai Pah Hills fault zone      0.195  <1,600,000   134  1308
#
#           AGE  ACODE  SLIPCODE SLIPDIRECT  FCODE  ... SLIPRTmmyr Comments  \
# 0     <15,000      2         3        NaN      1  ...      0.2-1      NaN
# 1    <130,000      3         3        NaN      1  ...      0.2-1      NaN
# 2  <1,600,000      5         4        NaN      1  ...       <0.2      NaN
# 3  <1,600,000      5         4        NaN      2  ...       <0.2      NaN
# 4    <130,000      3         4        NaN      1  ...       <0.2      NaN
#
# ...

# %%
faults_quarternary.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 22118 entries, 0 to 22117
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        22016 non-null  str
#  1   SLIPRATE_N  20633 non-null  str
#  2   RECENCY_N   20594 non-null  str
#  3   CODE        22118 non-null  int64
#  4   NUM         18508 non-null  str
#  5   AGE         21748 non-null  str
#  6   ACODE       22118 non-null  int64
#  7   SLIPCODE    22118 non-null  int64
#  8   SLIPDIRECT  4 non-null      str
#  9   FCODE       22118 non-null  int64
#  10  MAPPEDSCAL  18020 non-null  str
#  11  SECONDARYS  89 non-null     str
#  12  CFM_URL     2304 non-null   str
#  13  SLIPRTmmyr  19427 non-null  str
#  14  Comments    900 non-null    str
#  15  Geometry_C  14389 non-null  str
#  16  Notes       2 non-null      str
#  17  SlipRate_c  17849 non-null  str
#  18  Recency_ci  15485 non-null  str
#  19  DIPDIRECT   18242 non-null  str
# ...

# %% [markdown]
# # Geodetics

# %%
geodetics.head()
# Out:
#    long_wgs84  lat_wgs84  second_inv_strainrate_10e-9  dilationrate_10e-9  \
# 0 -111.086533  43.023580                          6.9                 0.7
# 1 -111.080377  43.023302                          6.8                 0.6
# 2 -111.074220  43.023023                          6.8                 0.6
# 3 -111.068064  43.022744                          6.8                 0.6
# 4 -111.061908  43.022465                          6.7                 0.6
#
#    shearrate_10e-9
# 0              4.5
# 1              4.5
# 2              4.5
# 3              4.5
# 4              4.5

# %%
geodetics.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1996714 entries, 0 to 1996713
# Data columns (total 5 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   long_wgs84                   float64
#  1   lat_wgs84                    float64
#  2   second_inv_strainrate_10e-9  float64
#  3   dilationrate_10e-9           float64
#  4   shearrate_10e-9              float64
# dtypes: float64(5)
# memory usage: 76.2 MB

# %% [markdown]
# # Great Basin Flows

# %%
great_basin_flows.head()
# Out:
#         Flow_Name Rock_Type          Age  SHAPE_Leng  SHAPE_Area  \
# 0  Buffalo Valley    Basalt      0.95 Ma         0.0         0.0
# 1  Buffalo Valley    Basalt      1.24 Ma         0.0         0.0
# 2  Buffalo Valley    Basalt  0.95-1.2 Ma         0.0         0.0
# 3  Buffalo Valley    Basalt      1.14 Ma         0.0         0.0
# 4  Buffalo Valley    Basalt  0.95-1.2 Ma         0.0         0.0
#
#                       Source Rock_Comp State Age_Source Geo_Age  AREA  \
# 0  ESRI/Googel Earth Imagery     mafic    NV        NaN     NaN   0.0
# 1  ESRI/Googel Earth Imagery     mafic    NV        NaN     NaN   0.0
# 2  ESRI/Googel Earth Imagery     mafic    NV        NaN     NaN   0.0
# 3  ESRI/Googel Earth Imagery     mafic    NV        NaN     NaN   0.0
# 4  ESRI/Googel Earth Imagery     mafic    NV        NaN     NaN   0.0
#
#    PERIMETER descriptio AgeSource Map_Symbol  \
# 0        0.0        NaN       NaN        NaN
# 1        0.0        NaN       NaN        NaN
# ...

# %%
great_basin_flows.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5281 entries, 0 to 5280
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Flow_Name   2667 non-null   str
#  1   Rock_Type   1568 non-null   str
#  2   Age         3913 non-null   str
#  3   SHAPE_Leng  5281 non-null   float64
#  4   SHAPE_Area  5281 non-null   float64
#  5   Source      5281 non-null   str
#  6   Rock_Comp   5281 non-null   str
#  7   State       5281 non-null   str
#  8   Age_Source  908 non-null    str
#  9   Geo_Age     1374 non-null   str
#  10  AREA        5281 non-null   float64
#  11  PERIMETER   5281 non-null   float64
#  12  descriptio  582 non-null    str
#  13  AgeSource   127 non-null    str
#  14  Map_Symbol  3720 non-null   str
#  15  geometry    5281 non-null   geometry
# dtypes: float64(4), geometry(1), str(11)
# memory usage: 660.3 KB

# %% [markdown]
# # Great Basin Vents

# %%
great_basin_vents.head()
# Out:
#   Rock_Comp              Age State Rock_Type Age_Source          Source  \
# 0     mafic  0.95 to 1.24 Ma    NV    Basalt        NaN  Buffalo Valley
# 1     mafic  0.95 to 1.24 Ma    NV    Basalt        NaN  Buffalo Valley
# 2     mafic  0.95 to 1.24 Ma    NV    Basalt        NaN  Buffalo Valley
# 3     mafic          1.14 Ma    NV    Basalt        NaN  Buffalo Valley
# 4     mafic  0.95 to 1.24 Ma    NV    Basalt        NaN  Buffalo Valley
#
#   Geo_Age Type  AREA  PERIMETER Name Descriptio Map_Symbol        Lat  \
# 0     NaN  NaN   0.0        0.0  NaN        NaN        NaN  40.365571
# 1     NaN  NaN   0.0        0.0  NaN        NaN        NaN  40.368904
# 2     NaN  NaN   0.0        0.0  NaN        NaN        NaN  40.380596
# 3     NaN  NaN   0.0        0.0  NaN        NaN        NaN  40.393598
# 4     NaN  NaN   0.0        0.0  NaN        NaN        NaN  40.346549
#
#          Long                         geometry
# 0 -117.273411  POINT Z (-117.27341 40.36557 0)
# ...

# %%
great_basin_vents.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1514 entries, 0 to 1513
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rock_Comp   1514 non-null   str
#  1   Age         714 non-null    str
#  2   State       1514 non-null   str
#  3   Rock_Type   306 non-null    str
#  4   Age_Source  282 non-null    str
#  5   Source      1514 non-null   str
#  6   Geo_Age     345 non-null    str
#  7   Type        753 non-null    str
#  8   AREA        1514 non-null   float64
#  9   PERIMETER   1514 non-null   float64
#  10  Name        395 non-null    str
#  11  Descriptio  496 non-null    str
#  12  Map_Symbol  302 non-null    str
#  13  Lat         1514 non-null   float64
#  14  Long        1514 non-null   float64
#  15  geometry    1514 non-null   geometry
# dtypes: float64(4), geometry(1), str(11)
# memory usage: 189.4 KB

# %% [markdown]
# # Paleo Geothermal

# %%
paleo_geothermal.head()
# Out:
#    FID_    Long_deg    Lat_deg                   Location State  Deposit_ty  \
# 0     1 -115.868206  38.365216               Abel Springs    NV  Travertine
# 1     2 -112.004452  43.035922  Alkali Flats Warm Springs    ID  Travertine
# 2     3 -117.338219  37.825604          Alkali Hot Spring    NV  Travertine
# 3     4 -117.337020  37.824204          Alkali Hot Spring    NV      Sinter
# 4     5 -117.338159  37.824778          Alkali Hot Spring    NV  Travertine
#
#                                         Map_unit  \
# 0                                             Qt
# 1  Sedimentary rocks (Permian and Pennsylvanian)
# 2                                             Qt
# 3                                           Qssi
# 4                                             Qt
#
#                           Ref_source  \
# 0                        Ayling_2020
# 1                         Ross, 1971
# 2  Ball_1901;Albers and Stewart_1972
# 3                        Faulds_2020
# ...

# %%
paleo_geothermal.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 709 entries, 0 to 708
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID_        709 non-null    int64
#  1   Long_deg    709 non-null    float64
#  2   Lat_deg     709 non-null    float64
#  3   Location    709 non-null    str
#  4   State       709 non-null    str
#  5   Deposit_ty  709 non-null    str
#  6   Map_unit    596 non-null    str
#  7   Ref_source  708 non-null    str
#  8   Comments    537 non-null    str
#  9   geometry    709 non-null    geometry
# dtypes: float64(2), geometry(1), int64(1), str(6)
# memory usage: 55.5 KB

# %% [markdown]
# # Qfaults

# %%
qfaults.head()
# Out:
#                                   NAME   NUM    DIPDIRECT SLIPDIRECT  \
# 0  Abert Rim fault, Lake Abert section  829a           NW        NaN
# 1  Abert Rim fault, Lake Abert section  829a           NW        NaN
# 2    Abert Rim fault, Northern section  829b           NW        NaN
# 3                    Adobe Range fault  1561           NW        NaN
# 4            Agai Pah Hills fault zone  1308  Unspecified        NaN
#
#   SLIPSENSE SECONDARY SLIPRT2023  SLIPRTNUM     REC2023   RECNUM  ...  \
# 0         N        RL       0.52      0.520     <15,000    15000  ...
# 1         N        LL       0.52      0.520     <15,000    15000  ...
# 2         N        LL       0.06      0.060  <1,600,000  1600000  ...
# 3         N       NaN       0.01      0.010  <1,600,000  1600000  ...
# 4        RL       NaN      0.195      0.195  <1,600,000  1600000  ...
#
#    RCODE2023  SCODE2023                  FTYPE_  MAPSCALE SLIPINFO RECINFO  \
# ...

# %%
qfaults.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 22956 entries, 0 to 22955
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        22956 non-null  str
#  1   NUM         19448 non-null  str
#  2   DIPDIRECT   18084 non-null  str
#  3   SLIPDIRECT  4 non-null      str
#  4   SLIPSENSE   19743 non-null  str
#  5   SECONDARY   89 non-null     str
#  6   SLIPRT2023  22956 non-null  str
#  7   SLIPRTNUM   22956 non-null  float64
#  8   REC2023     22956 non-null  str
#  9   RECNUM      22956 non-null  int64
#  10  CODE2023    22956 non-null  int64
#  11  FCODE2023   22956 non-null  int64
#  12  RCODE2023   22956 non-null  int64
#  13  SCODE2023   22956 non-null  int64
#  14  FTYPE_      22509 non-null  str
#  15  MAPSCALE    18897 non-null  str
#  16  SLIPINFO    18855 non-null  str
#  17  RECINFO     16442 non-null  str
#  18  COMMENTS    905 non-null    str
#  19  GEOCOMM     14462 non-null  str
# ...

# %% [markdown]
# # Seismicity Dependent

# %%
seismicity_dependent.head()
# Out:
#    long_wgs84  lat_wgs84  N50_alpha0pt05_10e-12_per_yr_m2  \
# 0     -122.00       37.0                            940.2
# 1     -121.95       37.0                           1069.0
# 2     -121.90       37.0                           1331.6
# 3     -121.85       37.0                           1879.6
# 4     -121.80       37.0                           2087.0
#
#    N50_alpha0pt1_10e-12_per_yr_m2  N50_alpha0pt15_10e-12_per_yr_m2  \
# 0                          1207.4                           1896.3
# 1                          1141.5                           1744.6
# 2                          1818.0                           2222.9
# 3                          2770.7                           3670.7
# 4                          4761.5                           6898.4
#
#    N100_alpha0pt05_10e-12_per_yr_m2  N100_alpha0pt1_10e-12_per_yr_m2  \
# 0                             746.5                           1108.5
# 1                             837.1                            888.8
# ...

# %%
seismicity_dependent.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26741 entries, 0 to 26740
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   long_wgs84                        26741 non-null  float64
#  1   lat_wgs84                         26741 non-null  float64
#  2   N50_alpha0pt05_10e-12_per_yr_m2   26741 non-null  float64
#  3   N50_alpha0pt1_10e-12_per_yr_m2    26741 non-null  float64
#  4   N50_alpha0pt15_10e-12_per_yr_m2   26741 non-null  float64
#  5   N100_alpha0pt05_10e-12_per_yr_m2  26741 non-null  float64
#  6   N100_alpha0pt1_10e-12_per_yr_m2   26741 non-null  float64
#  7   N100_alpha0pt15_10e-12_per_yr_m2  26741 non-null  float64
#  8   N200_alpha0pt05_10e-12_per_yr_m2  26741 non-null  float64
#  9   N200_alpha0pt1_10e-12_per_yr_m2   26741 non-null  float64
#  10  N200_alpha0pt15_10e-12_per_yr_m2  26741 non-null  float64
# dtypes: float64(11)
# memory usage: 2.2 MB

# %% [markdown]
# # Seismicity Independent

# %%
seismicity_independent.head()
# Out:
#    long_wgs84  lat_wgs84  N50_alpha0pt05_10e-12_per_yr_m2  \
# 0     -122.00       37.0                            746.6
# 1     -121.98       37.0                            711.9
# 2     -121.96       37.0                            635.2
# 3     -121.94       37.0                            600.8
# 4     -121.92       37.0                            555.6
#
#    N50_alpha0pt1_10e-12_per_yr_m2  N50_alpha0pt15_10e-12_per_yr_m2  \
# 0                           875.8                           1253.8
# 1                           889.9                           1305.8
# 2                           910.0                           1371.0
# 3                           899.7                           1438.2
# 4                           898.2                           1470.6
#
#    N100_alpha0pt05_10e-12_per_yr_m2  N100_alpha0pt1_10e-12_per_yr_m2  \
# 0                             767.9                           1509.3
# 1                             714.1                           1540.4
# ...

# %%
seismicity_independent.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 165851 entries, 0 to 165850
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   long_wgs84                        165851 non-null  float64
#  1   lat_wgs84                         165851 non-null  float64
#  2   N50_alpha0pt05_10e-12_per_yr_m2   165851 non-null  float64
#  3   N50_alpha0pt1_10e-12_per_yr_m2    165851 non-null  float64
#  4   N50_alpha0pt15_10e-12_per_yr_m2   165851 non-null  float64
#  5   N100_alpha0pt05_10e-12_per_yr_m2  165851 non-null  float64
#  6   N100_alpha0pt1_10e-12_per_yr_m2   165851 non-null  float64
#  7   N100_alpha0pt15_10e-12_per_yr_m2  165851 non-null  float64
#  8   N200_alpha0pt05_10e-12_per_yr_m2  165851 non-null  float64
#  9   N200_alpha0pt1_10e-12_per_yr_m2   165851 non-null  float64
#  10  N200_alpha0pt15_10e-12_per_yr_m2  165851 non-null  float64
# dtypes: float64(11)
# ...

# %% [markdown]
# # Study Area Boundary

# %%
study_area_boundary.head()
# Out:
#    CLASS           AREA    PERIMETER  \
# 0      1  494268.776844  3301.250941
#
#                                             geometry
# 0  POLYGON ((-119.25966 37.72854, -119.39199 37.9...

# %%
study_area_boundary.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CLASS      1 non-null      int64
#  1   AREA       1 non-null      float64
#  2   PERIMETER  1 non-null      float64
#  3   geometry   1 non-null      geometry
# dtypes: float64(2), geometry(1), int64(1)
# memory usage: 164.0 bytes

# %% [markdown]
# # Wellspring

# %%
# wellspring.head()
